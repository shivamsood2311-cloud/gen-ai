# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamsood2311-cloud/gen-ai/blob/main/python_for_generative_ai_G3_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyttsx3
# Initialize the TTS engine
engine = pyttsx3.init()
# Convert text to speech
engine.say("I will speak this text")
# Wait for the speech to finish
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4030043465.py in <cell line: 0>()
# ----> 1 import pyttsx3
#       2 # Initialize the TTS engine
#       3 engine = pyttsx3.init()
#       4 # Convert text to speech
#       5 engine.say("I will speak this text")
#
# ModuleNotFoundError: No module named 'pyttsx3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
_mycity = "Solan"
_mycity
# Out:
# 'Solan'

# %%
mysub = "python"
print(mysub)
# Out:
# python

# %%
mysub1 = "Generative Ai"
mysub1
# Out:
# 'Generative Ai'

# %%
#for variable naming, not use number on first positon
1mysub = "machine learning"
1mysub
# Out:
#   File "/tmp/ipython-input-4065684104.py", line 2
#     1mysub = "machine learning"
#     ^
# SyntaxError: invalid decimal literal

# %%
#for vairable naming we can not use space ,  symbol and keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#data type in python
#numeric
#1 integer---absence of decimal point is known as  integer
#ex -- 1,2,3,4...
x=1
type(x)
# Out:
# int

# %%
#floating point number--presence of decimal point
##ex--- 2.14,3.89,0.0
y=0.0
type(y)
# Out:
# float

# %%
#complex --- combination of real and imaginary
z = 3+4j
type(z)
# Out:
# complex

# %%
#string -- data in the form of text
x="Solan"
type(x)
# Out:
# str

# %%
#boolean--- used to store value in true and false
a= True
type(a)
# Out:
# bool

# %%
b=False
type(b)
# Out:
# bool

# %%
#none-- define a null value
e = None
type(e)
# Out:
# NoneType

# %%
 #single quotes string
 my_sub  = 'Generative ai'
 type(my_sub)
# Out:
# str

# %%
#double quotes string
my_college ="Shollini uni"
type(my_college)
# Out:
# str

# %%
#triple quotes
my_sentence ='''this is multi line sentence,
it is alse known as string'''
type(my_sentence)
# Out:
# str

# %%
my_sub="Machine learning"
print(my_sub)
# Out:
# Machine learning

# %%
len(my_sub) #len() is function which is length of string
# Out:
# 16

# %%
my_sub[0]
# Out:
# 'M'

# %%
my_sub[-3]
# Out:
# 'i'

# %%
my_sub[3:7:1]
# Out:
# 'hine'

# %%
#lower() ---this method convert string into lower case
my_sub = "PYTHON"
my_sub.lower()
# Out:
# 'python'

# %%
#upper() ---this method convert string into upper case
my_sub = "machine learning"
my_sub.upper()
# Out:
# 'MACHINE LEARNING'

# %%
#count()--- this method count particularly character in string
my_sub = "machine learning"
my_sub.count('a')
# Out:
# 2

# %%
#list is a collection of item , every item separated by comma and all items are  enclosed by square bracket it is  a mutable data system
my_list = [79,23,4,5,6,88]#homogeneous list
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [79, 23, 4, 5, 6, 88]

# %%
mixed_list =[76,2.14,"apple",True,None]#heterogenous list
type(mixed_list)
# Out:
# list

# %%
#indexing in list = location of item is known as indexing
my_list = [78,54,32,89,23]
0 1 2 3 4  positive indexing
-5 -4 -3 -2 -1 negative indexing
# Out:
#   File "/tmp/ipython-input-1491835437.py", line 3
#     0 1 2 3 4  positive indexing
#       ^
# SyntaxError: invalid syntax

# %%
#positive indexing
my_list = [78,54,32,89,23]
print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[3])
print(my_list[4])

# %%
#negative indexing
my_list =[78,23,45,6,7]
print(my_list[-1])
print(my_list[-2])
print(my_list[-3])
print(my_list[-4])
print(my_list[-5])

# %%
#slicing in list > grab the data upto designated point knowns as slicng
my_list = [98,78,38,46,34]
my_list[SI:EI:SS]
SI > included
Ei > excluded
SS > step size

# %%
my_list = [34,67,89,67,70]
my_list[0:4]

# %%
my_list[0:]

# %%
my_list[:4]

# %%
my_list[: :-1]

# %%
#function in list
print(my_list)

# %%
min(my_list)

# %%
max(my_list)

# %%
sum(my_list)

# %%
print(my_list)

# %%
#sorted() --this function arrange list in inc order or dec order
sorted(my_list,reverse=True)

# %%
#list function is not change in orginal list
print(my_list)

# %%
#append method this method add items end of the list
my_list.append(100)
print(my_list)

# %%
from posixpath import lexists
#extend this mthd merge list in another list
list1= [89,90,67]
list2 = [23,45,67]
list1.extend(list2)
print(list1)

# %%
#sort() this method used to arrange list into inc or dec or
my_list=[12,23,9,8,78]
my_list.sort()
my_list

# %%
#sort() this method used to arrange list into inc or dec or
my_list=[12,23,9,8,78]
my_list.sort(reverse=True)
my_list

# %%
#pop() -- this mthd remove item from list and take index index as a argument
list1= [12,13,14,15,16]
list1.pop()

# %%
#pop() -- this mthd remove item from list and take index as a argument
list1= [12,13,14,15,16]
list1.pop(3)

# %%
#remove() -- this mthd remove item from the list,take item as argument
my_list = [89,45,36,27]
my_list.remove(45)
print(my_list)

# %%
my_list

# %%
#dictionary collection of key value pairs ,key & value separated by colon,combination  of key AND value is known as item . Every item separated by ,(commma) all item are enclosed by curly bracels {}

# %%
#HP key SHM value
my_dict={"H.P":"SHM","U.P":"Lucknow"}
type(my_dict)

# %%
print(my_dict)

# %%
print(my_dict["H.P"])

# %%
my_dict={"H.P":"SHM","U.P":"Lucknow"}
type(my_dict)

# %%
#keys() -this method return keys of dictionary
list(my_dict.keys())

# %%
#values() --this method find values of the dictionary
list(my_dict.values())

# %%
#items() --this method returns item of dict
my_dict.items()

# %%
#get() --this method return value of te dict and take key as argument
my_dict.get("Name")

# %%
print(my_dict.get("age","age is not found"))

# %%
#update() --this method update the dict and tak dict as argument
my_dict.update({"age":20})
print(my_dict)

# %%
my_dict.update({"name":"dash"})
print(my_dict)

# %%
#conditional statement
#if -- this statement executes when condition is true
#elif -- this statement execute when cindition  is true
#else -- this statement execute if and elif condition is  false
age = int(input("enter your age:"))
if age>60:
  print("you are too old for marry")
elif age<18:
  print("you are too young for marry")
else:
  print("we will find a perfect match for you")

# %%
number = int(input("enter a number:"))
if number%2==0:
   print("Even")
else:
  print("Odd")

# %%
password = int(input("enter a password"))
if password == 1234:
  print("Access Granted")
else:
  print("Wrong password")

# %%
number = int(input("enter number one:"))
number1 = int(input("enter number two:"))
if number>number1:
  print("number one is greater")
elif number<number1:
    print("number two is greater")
else:
  print("both are equal")

# %%
time =float(input('enter time'))
if time >= 6.00 and time <18.00:
  print("day time")
else:
  print("night time")

# %%
number = int(input("enter number"))
if(i=0;i<11,i++)

# %%
name = input("Enter name: ")
print("Hello " + name)

# %%
my_dict = {"oho":"yes","ono":"no"}
type(my_dict)

# %%
print(my_dict)

# %%
my_dict.update({"aein":"why"})
print(my_dict)

# %%
list(my_dict.keys())

# %%
#user defined function ----- defined by user according to the need
def add() :
  a = int(input("Enter first number: "))
  b = int(input("Enter second number: "))
  c = a+b
  return c

# %%
print(add())

# %%
def multi() :
  a = int(input("Enter first number: "))
  b = int(input("Enter second number: "))
  c = a*b
  return c

# %%
print(multi())

# %%
#positional argument
def calculation(a,b):
  print("Addition",a+b)
  print("Substraction",a-b)
  print("Multiplication",a*b)
  print("Division",a/b)
  return "calculation is complete"

# %%
print(calculation(10,5))

# %%
#Default argument
def area_perimeter(width = 4,height = 8):
  area =  width*height
  perimeter = 2*(width+height)
  return "Area is",area,"and perimeter is",perimeter

# %%
print(area_perimeter(10,20))

# %%
#keyword argument
def interest(p,r,t):
  i = (p*r*t)/100
  return i

# %%
print(interest(r=10,p=1000,t=2))

# %%
#mix argument
print(interest(1000,t=2,r=10))

# %%
print(interest(p=1000,r=10,2))

# %%
from typing_extensions import TypeVarTuple
#variable length argument
#non keyword variable length argument (1)
#keyword variable length argument(2)
#2 is behave as dict
#2 is represent by double star(**)
#1 is behave as TypeVarTuple
#1 is represented by star(*)

# %%
#non keyword variable length argument
def test(*args):
  print(args)
  print(len(args))
  print(type(args))

# %%
test(2,3,4,5,6)

# %%
def sum_number(*args):
  sum =0
  for num in args:
    sum+=num
    return sum

# %%
sum_number(1,2,3,4,5,6)

# %%
#for num in args:
#sum += num
#return num

# %%
#key word variable  length argument
def test(**kwargs):
  print(len(kwargs))
  print(type(kwargs))

# %%
test(a=10,b=20,c=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2555137747.py in <cell line: 0>()
# ----> 1 test(a=10,b=20,c=30)
#
# NameError: name 'test' is not defined

# %%
def pass_student(**kwargs):
  pass_students_list = []
  for name, marks in kwargs.items() :
    if marks>35:
      pass_students_list.append(name)
      return pass_students_list

# %%
def print_hello() :
  print("helo")
  print_hello()

# %%
def calc_avg(a,b,c):
   sum = a+b+c
   avg=sum/3
   return avg

calc_avg(10,20,30)
# Out:
# 20.0

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
my_suib="achime actime"
my_suib[2::3]
# Out:
# 'hecm'

# %%
algorithm="Neural raNetworrak"
algorithm.count('ra')
# Out:
# 3

# %%
algorithm.find('N')
# Out:
# 0

# %%
algorithm.replace(' ','__')
# Out:
# 'Neural__raNetworrak'

# %%
age=int(input("enter age:"))
if age<18:
  print("you can't marry")
elif age>18:
 print("yes you can marry")
else :
  print("you can't marry")
# Out:
# enter age:19
# yes you can marry

# %%
for i in range(len(my_suib)):
  print(my_suib[i],i)
# Out:
# a 0
# c 1
# h 2
# i 3
# m 4
# e 5
#   6
# a 7
# c 8
# t 9
# i 10
# m 11
# e 12

# %%
my_listt=[100,200,300,400,500]
for i in my_listt:
  print(i)
# Out:
# 100
# 200
# 300
# 400
# 500

# %%
i=0
while i<6:
  i+=1
if i==3:
  break
   print(i)
else:
  print(i)
# Out:
#   File "/tmp/ipython-input-332584631.py", line 4
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
while i<6:
  i+=1
  if i==2:
    continue
    print(i)
  else:
    print(i)

# %%
def add():
  a=int(input("enter first number:"))
  b=int(input("enter second number:"))
  return a+b
  add()

# %%
def test(*args):
  print(*args)
  print(len(args))
  print(type(args))
test(1,2,3,4,5,6)
# Out:
# 1 2 3 4 5 6
# 6
# <class 'tuple'>

# %%
def sum_num(*args):
  sum=0
  for num in args:
      sum+=num
  return sum
sum_num(2,3,4,5,6)
# Out:
# 20

# %%
def pass_student(**kwargs):
  pass_student_list=[]
  for key, value in kwargs.items():
    if value>33:
      pass_student_list.append(key)
  return pass_student_list

pass_student(a=30,b=90,c=91,d=35)
# Out:
# ['b', 'c', 'd']

# %%
state_list=['U.P','M.P','bih']
city_list=['Luck','bho','saha']
x=zip(state_list,city_list)
print(dict(x))
# Out:
# {'U.P': 'Luck', 'M.P': 'bho', 'bih': 'saha'}

# %%
def area_perimeter(width=2,height=2):
  area=width*height
  perimeter=2*(width+height)
  print("area="+str(area)+"and perimeter="+str(perimeter))

# %%
print(twood_array{1}{3})

# %%
import numpy as np
my_array = np.array([1,2,3,4])
print(my_array)
power_array = np.power(my_array,2)
print(power_array)
# Out:
# [1 2 3 4]
# [ 1  4  9 16]

# %%
import numpy as np
my_array = np.array([1,2,3,4])
print(my_array)
log_array = np.log(my_array)
print(log_array)
# Out:
# [1 2 3 4]
# [0.         0.69314718 1.09861229 1.38629436]

# %%
import numpy as np
my_array = np.array([1,2,3,4])
print(my_array)
log2_array = np.log2(my_array)
print(log2_array)
# Out:
# [1 2 3 4]
# [0.        1.        1.5849625 2.       ]

# %%
import numpy as np
my_array = np.array([1,2,3,4])
print(my_array)
log10_array = np.log10(my_array)
print(log10_array)
# Out:
# [1 2 3 4]
# [0.         0.30103    0.47712125 0.60205999]

# %%
import numpy as np
my_array = np.array([1,2,3,4])
print(my_array)
exp_array = np.exp(my_array)
print(exp_array)
# Out:
# [1 2 3 4]
# [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
#matplotlib---> it is python library   , use for data visualization
import matplotlib.pyplot as plt(allias)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
0#inline plot
import numpy as np
import matplotlib.pyplot as plt
xpoint = np.array([0,3])
ypoint = np.array([2,4])
plt.plot(xpoint,ypoint)
plt.show()
